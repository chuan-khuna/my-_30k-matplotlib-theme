# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from utils.vis_utils import *
from utils.vis_utils.palettes import ft, economist, nzk, london_dark, economist_graphic

# %%
n = 100
num_series = 5

df = pd.DataFrame(
    np.random.randn(n, num_series),
    index=np.arange(n),
    columns=[f'fake {i+1}' for i in range(num_series)],
)

df = df.cumsum()

# %%
figsize = (6, 4)

# %%
use_style('ft')
set_seaborn_palette(ft.vis_colors.values())

fig = plt.figure(figsize=figsize)

for col in df.columns:
    sns.lineplot(
        x=df.index, y=df[col], path_effects=get_path_effects(3, foreground=ft.text_colors['wheat'])
    )

plt.title('FT')
plt.xlabel('')
plt.ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
use_style('nzk')
set_seaborn_palette(nzk.main_colors.values())

fig = plt.figure(figsize=figsize)
for col in df.columns:
    sns.lineplot(
        x=df.index, y=df[col], path_effects=get_path_effects(3, foreground=nzk.text_colors['bg'])
    )

plt.title('nzk')
plt.xlabel('')
plt.ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
use_style('economist')
set_seaborn_palette(economist.main_colors.values())

fig = plt.figure(figsize=figsize)
for col in df.columns:
    sns.lineplot(
        x=df.index,
        y=df[col],
        path_effects=get_path_effects(3, foreground=economist.text_colors['bg']),
    )

plt.title('economist')
plt.xlabel('')
plt.ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
use_style('london_dark')
set_seaborn_palette(london_dark.main_colors.values())

fig = plt.figure(figsize=figsize)
for col in df.columns:
    sns.lineplot(
        x=df.index,
        y=df[col],
        path_effects=get_path_effects(3, foreground=london_dark.text_colors['bg-light']),
    )

plt.title('london dark')
plt.xlabel('')
plt.ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
use_style('economist_graphic')
set_seaborn_palette(economist_graphic.main_colors.values())

for col in df.columns:
    sns.lineplot(
        x=df.index,
        y=df[col],
        path_effects=get_path_effects(3, foreground=economist_graphic.text_colors['bg']),
    )

plt.title('Economist Graphic Detail\n16:9 aspect ratio')
plt.xlabel('')
plt.ylabel('')
# Out:
# Text(0, 0.5, '')
